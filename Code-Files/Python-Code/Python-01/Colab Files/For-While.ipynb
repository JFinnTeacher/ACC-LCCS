# %% [markdown]
# # For and While Loops (Iteration)

# %% [markdown]
# ## While Loops

# %% [markdown]
# ![Screenshot_20240926_101513.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot_20240926_102224.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot_20240926_102312.png](data:image/png;base64,...)

# %% [markdown]
# ## For Loops
#
# ![Screenshot_20240926_102422.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot_20240926_102504.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot_20240926_102540.png](data:image/png;base64,...)
