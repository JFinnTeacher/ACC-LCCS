# %% [markdown]
# # If elif Else
#
# Add Comments to the Code below explaining what is happening in each section

# %%
#
import random

number = random.randint(1, 10)
# print(number)

guess = int(input("Enter a Number between 1 and 10: "))

#
if guess == number:
  print("Your guess was correct")
  print("Well Done")

print("Goodbye")
# Out:
# Enter a Number between 1 and 10: 6
# Goodbye

# %% [markdown]
# Copy and Modify the code as outlined in class
