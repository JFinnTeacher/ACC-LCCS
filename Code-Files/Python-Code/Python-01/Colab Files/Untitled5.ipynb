# %%
counter = 0
while counter <= 1000000:
  print(counter)
  counter += 1

# %%
startNumber = chr(input("What is your first Number: "))
endNumber = int(input("What is the end Number: "))
total = 0
counter = startNumber
while letter != "z":
  print(counter)
  total = total + counter
  counter += 1 # Increment by 1

print(total)
# Out:
# What is your first Number: 1
# What is the end Number: 5
# 1
# 2
# 3
# 4
# 5
# 15

# %%
inputletter = input("please enter a letter: ")
while inputletter != "z":
	print("the entered letter is :",inputletter)
	inputletter = input("please enter another letter: ")
print("this is outside the loop")
# Out:
# please enter a letter: y
# the entered letter is : y
# please enter another letter: r
# the entered letter is : r
# please enter another letter: Z
# the entered letter is : Z
# please enter another letter: z
# this is outside the loop
