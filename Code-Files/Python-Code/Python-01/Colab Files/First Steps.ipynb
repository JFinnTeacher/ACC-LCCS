# %%
10/8
# Out:
# 1.25

# %% [markdown]
# # Some Text
#
# This is text
# This is **Bold**
# ## Heading 2
# ### Heading 3

# %%
print("Hello World")
print("Second Line")
# Out:
# Hello World
# Second Line
