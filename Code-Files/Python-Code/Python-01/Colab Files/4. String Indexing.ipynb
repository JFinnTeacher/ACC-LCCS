# %% [markdown]
# # String Indexing
#
# Expirment:
#
# A **pangram** is a sentence that uses all 27 letters of the Alphabet at leat once. Study the program below and try to predict what the output will be.
#
# Record the prediction in the next text box.
#
# Key in the program to see if your prediction is correct. Make changes to the code and observe what happens
#
# ![Screenshot from 2024-09-22 18-56-52.png](data:image/png;base64,...)

# %% [markdown]
# ## Prediction
