# %% [markdown]
# # Python: Average Height Exercise
#
# **Note: This is worth 20% of your Continuous Assessment grade.**
#
# Submission:
#
# Task:
#
# Design and implement a program to find the average of five heights.
#
# Your program should:
# - Ask the end-user to input five heights.
# - Calculate the average (mean) of the five heights
# - Display the answer to the user.
# - Have comments to show what you are doing
# - Run without any syntax errors (brackets, spacing, quotes etc)
# - Run without any bugs (test using data below)
#
# Test your program with the following data:
#
# ![Table.png](data:image/png;base64,...)
#
# Once you are satisfied that it works, try to do the following:
#
# - Copy the code Block and Modify the code so that it can accept decimal values for height as well as whole numbers.  Round your result to two decimal places.
#
# - Add a line of code to display  the result in inches as well as centimetres.
# (1 cm = 0.393701 inches)
#
# **NOTE: COMMENT OUT CODE THAT DOESN’T WORK (DO NOT DELETE IT).  YOU CAN ADD COMMENTS TO EXPLAIN WHAT YOU ARE TRYING TO DO.**
