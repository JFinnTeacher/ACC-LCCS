# %%
age = int(input("What is your age: "))

if age < 17:
  print("You are not eligable to Drive!")
elif age == 17:
  print("You are the exact age for a licence")
else:
  print("You can Drive!")
# Out:
# What is your age: 17
# You are the exact age for a licence
