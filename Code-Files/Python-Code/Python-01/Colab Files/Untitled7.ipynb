# %%
name = input("Please enter your name: ")
print("Hello", name)

# %%
birthYear = int(input("Type in the year you were born: "))
print("You are", 2024-birthYear, "Years old")
# Out:
# Type in the year you were born: nineteen eighty six
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-aad9934d6160> in <cell line: 1>()
# ----> 1 birthYear = int(input("Type in the year you were born: "))
#       2 print("You are", 2024-birthYear, "Years old")
#
# ValueError: invalid literal for int() with base 10: 'nineteen eighty six'

# %%
string1 = "Hello"
string2 = "World"
string3 = string1+" "+string2+"!"
# string3 = string3.lower()
length = len(string3)
print(string3)
print(length)
print(string3[3:4])
string4 = string1*3
print(string4)
# Out:
# Hello World!
# 12
# l
# HelloHelloHello
