# %% [markdown]
# # Print Ascii Art Instructions:
#
# We want to print the following to the screen in python: **lamas are lovely**
#
#
# You must first do THREE things to it:
#
#
# ``` python
# print("Llamas are lovely")
# ```
#
#
#
# Can you spot them all?
#
#
# 1.   add a print (with a small p!)
# 2.   add brackets ()
# 3.   add quotation marks " "
#
#
# Click the Play button below to test it out

# %%
print("lololocopter")
# Out:
# lololocopter

# %%
# You can use the hashtag symbol to add a comment (see how the text is green?)
# These are for HUMANS ONLY and don't affect your code

print("Code never lies. Comments sometimes do 😊  ")

# %% [markdown]
# ## Easy Task: Print
#
# Make a print statement that prints something to the screen.

# %%
# 🟩 EASY TASK 🟩 Do the easy task here

# %% [markdown]
# ## Medium Task: Multiple Lines
#
# **But that's boring!**
#
# Let's get make ASCII ART!!!! ASCII is the system used for keyboard letters and symbols. When you type "a" on a keyboard, it sends the binary number 65 down that wire to the computer. When all countries agreed that 65 would mean a and 66 would mean be, that became STANDARD CODE as in American Standard Code, ASC.
#
# Below are some links for text to ASCII art generators and general ASCII art.
#
#
#
# *   [Text to Ascii ART](https://patorjk.com/software/taag/#p=display&f=Graffiti&t=ascii%20art)
# *   [Ascii Art to copy paste](https://www.asciiart.eu/comics/batman)
#
#
#
# You can either use TRIPLE QUOTES here to avoid an error or add print on every line

# %%
print("""

                     .__.__
_____    ______ ____ |__|__|
\__  \  /  ___// ___\|  |  |
 / __ \_\___ \\  \___|  |  |
(____  /____  >\___  >__|__|
     \/     \/     \/


""")

# %%
print("                     .__.__     ")
print("_____    ______ ____ |__|__|    ")
print("\__  \  /  ___// ___\|  |  |    ")
print(" / __ \_\___ \\  \___|  |  |    ")
print("(____  /____  >\___  >__|__|    ")
print("     \/     \/     \/           ")

# %% [markdown]
# **Your medium task:**
#
# Use print("") to make some ascii art below.
#
# TIP: Using the \ can sometimes cause problems as this "escapes" the following character. It's used for example if you want to actually print a quotation marks, you'd print \" but ascii art sometimes uses the backslash \ symbol to draw things. You can solve this by any of these fixes
# 1.  Leaving a space after any \ symbol
# 2.  Using print with triple quotes
# 3.  Avoiding any ascii art with the \ symbol

# %%
# 🟧 Medium Task 🟧 Do the medium task here. Create some ASCII ART yourself or use the links

# %% [markdown]
# ## Hard Task: \n New Lines
#
# Space out your ASCII art by adding in some newlines with /n
#
#
# Try using /n to create white space.

# %%
print("\n This \n is \n spaced \n out")
# Out:
#  This
#  is
#  spaced
#  out

# %% [markdown]
# This is your hard task:
#
# Create a game menu system that has ASCII art at the top eg. a knight or dragon and then a game menu that has thee options below it like:
#
# ```
# Welcome to my game
#     @
#    \ /
#     ><
#     \|
#
# - Start (n)ew game
# - (l)oad save game
# - (q)uit game
#
# ```

# %%
# 🟥 Hard Task 🟥 Create a Menu system that has ASCII ART here
