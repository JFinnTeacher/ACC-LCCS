# %% [markdown]
# **Exercise 01**

# %% [markdown]
# ![Menu.png](data:image/png;base64,...)
#
# 01 Key in the code above, make sure it runs without errors.

# %% [markdown]
# 02 Design and implement a menu for an application of your choice (Example: Game Instructions, Online Library Menu, Fast Food Order Screen)
#
# You can use a blank page to design it before you program.
