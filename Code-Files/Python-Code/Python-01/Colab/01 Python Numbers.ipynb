# %%
x = int(input(""))
y = float(input())

print("addition is", x+y)
print("subtraction is", x-y) # Floor division is
print("multiplication is", x*y)
print("Remainder(Root) is", x%y)
print("Division is", x/y)
print("Floor Division is", x//y)
print("power is", x**y)
# Out:
# 5
# 9
# addition is 14.0
# subtraction is -4.0
# multiplication is 45.0
# Remainder(Root) is 5.0
# Division is 0.5555555555555556
# Floor Division is 0.0
# power is 1953125.0
