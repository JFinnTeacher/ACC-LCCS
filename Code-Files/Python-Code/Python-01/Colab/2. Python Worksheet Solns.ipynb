# %% [markdown]
# ![Picture1.png](data:image/png;base64,...)

# %%
qtyMars = 5
costOfMars = qtyMars * 1
costOfCoke = 4 * 1.5
qtyCrisps = 3
unitCostOfCrisps = 0.8
costOfCrisps = qtyCrisps * unitCostOfCrisps
costOfTea = 2 * 2
costOfBread = 3.5
total = costOfMars+costOfCoke+costOfCrisps+costOfTea+costOfBread
print("The Total cost is ", total)
# Out:
# The Total cost is  20.9

# %% [markdown]
# ![Picture2.png](data:image/png;base64,...)

# %% [markdown]
# ![Picture3.png](data:image/png;base64,...)

# %% [markdown]
# Can you re order the code above without breaking the program

# %% [markdown]
# ![Picture4.png](data:image/png;base64,...)

# %% [markdown]
# Enter the Frist code block here

# %% [markdown]
# Enter the second code block here

# %% [markdown]
# Add comments to the code explaining the following
#
#
# *   Explain the purpose of the variables low and high
# *   Why is the Variable low used in Line 5
# *   Explain the purpose of the brackets in line 15
#
# Modify the Code into the code block below to use a running total
