# %% [markdown]
# # Python Variable Practice
#
#
# Practice using comments by putting a comment before each exercise.
# Example:
# ```python
# #Exercise 1: Printing a variable.
# ```
# ## Exercise 1
# Create program that initialises a variable called apples.  Set the value of apples to 4.  Print the number of apples.

# %% [markdown]
# ## Exercise 2
# Create a program that initialises a variable called userName and set it equal to Bob.  Print the userName.

# %% [markdown]
# ## Exercise 3:
# Create a program that uses the input command to ask the user to enter their name.  Print the users name.

# %% [markdown]
# ## Exercise 4:
# Expand Ex 3 to print a message to the user.  For example if they entered Ann, it would print Hello Ann.

# %% [markdown]
# ## Exercise 5:
# Create a program that acts as a restaurant booking system.
# Ask the user for their name, number of people and time they would like a reservation for.
#
# The program should print a message to the user telling them their table is booked.  The message should look like this.
#
# **John has booked a table for 4 people at 8 o’clock**

# %% [markdown]
# ## Exercise 6
#
# Operations (+, - ,* and / ) may not work unless the correct datatype (string, int, float) is being used.
#
# Type the following into Python to see which ones work.  You will have to put them into a print statement.
# ```
# a) 2 * 3
# b) 72.1 / "8"
# c) "10" + 2
# d) "I have" + 3 + "apples"
# e) "To Infinity" + "and" + "Beyond!"
# f) "bouncy" * 5
# ```
#
# For the operations that dont work use a conversion function to convert one of the variables to a type that will work correctly. Remember
#
# ```
# str() - Converts to a string
# int() - Converts to an integer
# float() - Converts to a floating point number
# ```

# %% [markdown]
# ## Exercise 7
# Create a program that asks the user to enter a number, multiples it by 10 and tells us the answer.
#
# Hint: You will need to convert the input to a number

# %% [markdown]
# ## Exercise 8
#
# Create a program that asks the user to enter two numbers and prints out the
# 1.   product of the numbers.
# 2.   sum of the numbers
# 3. difference between the numbers

# %% [markdown]
# ## Exercise 9
# Create a program that asks the user to enter their name and their age.
# Print out a personalised message that tells them the year they will turn 100 years old.
#
# (You can assume that they have already had their birthday this year)

# %% [markdown]
# ![Picture2.png](data:image/png;base64,...)

# %% [markdown]
# Centigrade - Farenheit

# %% [markdown]
# ## Exercise 11
# Find out how far in miles your school is from Singapore.  Write a program that converts this distance to kilometers and displays it to the nearest kilometer.  One mile equals 1.60935km.
#
# You have decided to charter a helicopter to fly you and some friends from your school to Singapore at a cost of €900per km.  Calculate and display the cost of the flight.
